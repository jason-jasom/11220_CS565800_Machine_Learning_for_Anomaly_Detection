# %%
! gdown 1C9OaAfpOlT7nChRYnDISNjiMeM5zSnx-
! unzip upload3.zip
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=17RPSRhiyjsbSUCmfWPq5Bw7LF5eeHpej
# From (redirected): https://drive.google.com/uc?id=17RPSRhiyjsbSUCmfWPq5Bw7LF5eeHpej&confirm=t&uuid=e974a379-76f2-438f-b7c1-ff6a4b88f015
# To: /content/upload3.zip
# 100% 42.9M/42.9M [00:00<00:00, 60.1MB/s]
# Archive:  upload3.zip
#   inflating: aggregate.py
#   inflating: dataset.py
#   inflating: detect/avenue_test_detect_result_yolov3.pkl
#   inflating: detect/avenue_train_detect_result_yolov3.pkl
#   inflating: detect/ped2_test_detect_result_yolov3.pkl
#   inflating: detect/ped2_train_detect_result_yolov3.pkl
#   inflating: detect/shanghaitech_test_detect_result_yolov3.pkl
#   inflating: detect/shanghaitech_train_detect_result_yolov3.pkl
#   inflating: figs/arch.png
#   inflating: gen_patches.py
#   inflating: LICENSE
#   inflating: main.py
#  extracting: models/__init__.py
#   inflating: models/__pycache__/__init__.cpython-311.pyc
# ...

# %%
! gdown 1C0C3jcHMO6q_TA-qbQJeyENMyWd-Bo3d
! unzip avenue_custom.zip
! mv avenue ../
# Out:
# 串流輸出內容已截斷至最後 5000 行。
#   inflating: avenue/training/04/0957.jpg
#   inflating: avenue/training/04/0958.jpg
#   inflating: avenue/training/04/0959.jpg
#   inflating: avenue/training/04/0960.jpg
#   inflating: avenue/training/04/0961.jpg
#   inflating: avenue/training/04/0962.jpg
#   inflating: avenue/training/04/0963.jpg
#   inflating: avenue/training/04/0964.jpg
#   inflating: avenue/training/04/0965.jpg
#   inflating: avenue/training/04/0966.jpg
#   inflating: avenue/training/04/0967.jpg
#   inflating: avenue/training/04/0968.jpg
#   inflating: avenue/training/04/0969.jpg
#   inflating: avenue/training/04/0970.jpg
#   inflating: avenue/training/04/0971.jpg
#   inflating: avenue/training/04/0972.jpg
#   inflating: avenue/training/04/0973.jpg
#   inflating: avenue/training/04/0974.jpg
#   inflating: avenue/training/04/0975.jpg
#   inflating: avenue/training/04/0976.jpg
#   inflating: avenue/training/04/0977.jpg
#   inflating: avenue/training/04/0978.jpg
# ...

# %%
! python gen_patches.py --dataset avenue --phase train --filter_ratio 0.9 --sample_num 5
# Out:
# Load 8 videos 10315 frames, 44864 objects, in 0.05488705635070801 s.
# 100% 44864/44864 [06:52<00:00, 108.77it/s]

# %%
! python gen_patches.py --dataset avenue --phase test --filter_ratio 0.9 --sample_num 5
# Out:
# Load 5 videos 5527 frames, 21802 objects, in 0.02941441535949707 s.
# 100% 21802/21802 [03:42<00:00, 97.92it/s]

# %%
! python main.py --dataset avenue --print_interval 20 --batch_size 192 --sample_num 5 --epochs 20 --static_threshold 0.2
# Out:
# 2024-05-30 09:01:52.237210: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-30 09:01:52.237256: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-30 09:01:52.339507: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-05-30 09:01:52.555340: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
! python main.py --dataset avenue --sample_num 5 --checkpoint checkpoint/best_2024-05-30-09-02-01.pth
# Out:
# 2024-05-30 10:12:47.759903: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-30 10:12:47.759951: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-30 10:12:47.854042: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-05-30 10:12:48.056941: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
from itertools import permutations
import numpy as np
t_stand = tuple(i for i in range(5))
t_per = permutations(t_stand)
perm = np.random.permutation(5)
t_label = np.array([list(t_per).index(tuple(i for i in perm))])

# %%
t_label
# Out:
# array([36])

# %%
perm
# Out:
# array([1, 3, 0, 2, 4])
